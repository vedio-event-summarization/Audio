# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
import librosa
import IPython.display
import librosa.display
# %matplotlib inline
from scipy.signal import butter, lfilter, freqz
from scipy.fftpack import fft
from scipy.fftpack import fft,fftfreq
# Out:
# /usr/local/lib/python2.7/dist-packages/librosa/__init__.py:40: DeprecationWarning: You are using librosa with Python 2. Please note that librosa 0.7 will be the last version to support Python 2, after which it will require Python 3 or later.
#   DeprecationWarning)

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))
   

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
    
    print(fftabs1.shape)
    print(freqs1.shape)
    
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('hi.wav')
# Out:
# (220160,)
# (220160,)

# %%
calc_R('goal.wav')
# Out:
# (220160,)
# (220160,)

# %%
calc_R('lo2.wav')
# Out:
# (220160,)
# (220160,)

# %%
calc_R('lo1.wav')
# Out:
# (220160,)
# (220160,)

# %%
from scipy import stats

# %%
stats.describe(fftabs1[:int(freqs1.size/2)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9160978fc81b> in <module>()
# ----> 1 stats.describe(fftabs1[:int(freqs1.size/2)])
#
# NameError: name 'fftabs1' is not defined

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))
   

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
    
    print(fftabs1.shape)
    print(freqs1.shape)
    
    print(stats.describe(fftabs1[:int(freqs1.size/2)]))
    
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('hi.wav')
# Out:
# (220160,)
# (220160,)
# DescribeResult(nobs=110080, minmax=(1.0153724e-05, 8.661713), mean=0.28994095, variance=0.27868485, skewness=3.239861249923706, kurtosis=15.202224288470138)

# %%
calc_R('lo2.wav')
# Out:
# (220160,)
# (220160,)
# DescribeResult(nobs=110080, minmax=(1.3110908e-05, 14.8373995), mean=0.19037153, variance=0.16519886, skewness=4.977995872497559, kurtosis=53.79938006053739)

# %%
calc_R('goal.wav')
# Out:
# (220160,)
# (220160,)
# DescribeResult(nobs=110080, minmax=(3.536112e-05, 13.501901), mean=0.25188956, variance=0.28416574, skewness=4.8669610023498535, kurtosis=37.978255815365074)

# %%
calc_R('lo1.wav')
# Out:
# (220160,)
# (220160,)
# DescribeResult(nobs=110080, minmax=(3.69952e-05, 12.265745), mean=0.19093686, variance=0.13740946, skewness=3.9915008544921875, kurtosis=31.434631365309627)

# %%
calc_R('low.wav')
# Out:
# (220160,)
# (220160,)
# DescribeResult(nobs=110080, minmax=(2.9603398e-06, 8.423577), mean=0.11398473, variance=0.0930569, skewness=9.420296669006348, kurtosis=140.66416889315073)

# %%
from scipy.stats import gmean

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))
   

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
    
    Moment=[]
    for i in range(0,9):
        j = moment(fftabs1[:int(freqs1.size/2)], moment=i)
        Moment.append(j)
        
    print(stats.describe(fftabs1[:int(freqs1.size/2)]))
    print(gmean(fftabs1[:int(freqs1.size/2)]))
    print(Moment)
    
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('hi.wav')
# Out:
# (220160,)
# (220160,)
# DescribeResult(nobs=110080, minmax=(1.0153724e-05, 8.661713), mean=0.28994095, variance=0.27868485, skewness=3.239861249923706, kurtosis=15.202224288470138)
# 0.06625353

# %%
calc_R('goal.wav')
# Out:
# (220160,)
# (220160,)
# DescribeResult(nobs=110080, minmax=(3.536112e-05, 13.501901), mean=0.25188956, variance=0.28416574, skewness=4.8669610023498535, kurtosis=37.978255815365074)
# 0.067468934

# %%
calc_R('lo2.wav')
# Out:
# (220160,)
# (220160,)
# DescribeResult(nobs=110080, minmax=(1.3110908e-05, 14.8373995), mean=0.19037153, variance=0.16519886, skewness=4.977995872497559, kurtosis=53.79938006053739)
# 0.03800931

# %%
calc_R('lo1.wav')
# Out:
# (220160,)
# (220160,)
# DescribeResult(nobs=110080, minmax=(3.69952e-05, 12.265745), mean=0.19093686, variance=0.13740946, skewness=3.9915008544921875, kurtosis=31.434631365309627)
# 0.046832427

# %%
calc_R('low.wav')
# Out:
# (220160,)
# (220160,)
# DescribeResult(nobs=110080, minmax=(2.9603398e-06, 8.423577), mean=0.11398473, variance=0.0930569, skewness=9.420296669006348, kurtosis=140.66416889315073)
# 0.029734781

# %%
from scipy.stats import moment

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))
   

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
    
    #Moment=[]
    #for i in range(0,9):
        #j = moment(fftabs1[:int(freqs1.size/2)], moment=i)
        #Moment.append(j)
        
    res = stats.cumfreq(fftabs1, numbins=25)
    x = res.lowerlimit + np.linspace(0, res.binsize*res.cumcount.size,
                                 res.cumcount.size)
    
    fig = plt.figure(figsize=(10, 4))
    ax1 = fig.add_subplot(1, 2, 1)
    ax2 = fig.add_subplot(1, 2, 2)
    ax1.hist(samples, bins=25)
    ax1.set_title('Histogram')
    ax2.bar(x, res.cumcount, width=res.binsize)
    ax2.set_title('Cumulative histogram')
    ax2.set_xlim([x.min(), x.max()])

    print(stats.describe(fftabs1[:int(freqs1.size/2)]))
    print(gmean(fftabs1[:int(freqs1.size/2)]))
    #print(Moment)
    
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('hi.wav')
# Out:
# DescribeResult(nobs=110080, minmax=(1.0153724e-05, 8.661713), mean=0.28994095, variance=0.27868485, skewness=3.239861249923706, kurtosis=15.202224288470138)
# 0.06625353
# [1.0, 0.0, 0.27868232, 0.47664008, 1.4136546, 5.2303724, 23.75948, 127.49308, 781.2007]

# %%
calc_R('goal.wav')
# Out:
# DescribeResult(nobs=110080, minmax=(3.536112e-05, 13.501901), mean=0.25188956, variance=0.28416574, skewness=4.8669610023498535, kurtosis=37.978255815365074)
# 0.067468934
# [1.0, 0.0, 0.28416315, 0.737241, 3.3089406, 21.002462, 177.80852, 1827.0845, 21008.053]

# %%
calc_R('lo2.wav')
# Out:
# DescribeResult(nobs=110080, minmax=(1.3110908e-05, 14.8373995), mean=0.19037153, variance=0.16519886, skewness=4.977995872497559, kurtosis=53.79938006053739)
# 0.03800931
# [1.0, 0.0, 0.16519736, 0.3342406, 1.5500646, 12.771639, 143.40414, 1821.5673, 24379.135]

# %%
calc_R('lo1.wav')
# Out:
# DescribeResult(nobs=110080, minmax=(3.69952e-05, 12.265745), mean=0.19093686, variance=0.13740946, skewness=3.9915008544921875, kurtosis=31.434631365309627)
# 0.046832427
# [1.0, 0.0, 0.13740821, 0.20330837, 0.65016085, 3.8862767, 35.324265, 381.31445, 4379.475]

# %%
calc_R('low.wav')
# Out:
# DescribeResult(nobs=110080, minmax=(2.9603398e-06, 8.423577), mean=0.11398473, variance=0.0930569, skewness=9.420296669006348, kurtosis=140.66416889315073)
# 0.029734781
# [1.0, 0.0, 0.09305605, 0.2674124, 1.2440497, 6.9143324, 42.310886, 274.91953, 1861.0775]

# %%
from scipy import stats
