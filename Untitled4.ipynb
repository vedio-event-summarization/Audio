# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
import librosa
import IPython.display
import librosa.display
# %matplotlib inline
from scipy.signal import butter, lfilter, freqz
from scipy.fftpack import fft
from scipy.fftpack import fft,fftfreq
from scipy import stats
from scipy.stats import gmean
from scipy.stats import moment
# Out:
# /usr/local/lib/python2.7/dist-packages/librosa/__init__.py:40: DeprecationWarning: You are using librosa with Python 2. Please note that librosa 0.7 will be the last version to support Python 2, after which it will require Python 3 or later.
#   DeprecationWarning)

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)

# %%
from scipy.signal import hilbert

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
    analytic_signal = hilbert(fftabs1)
    amplitude_envelope = np.abs(analytic_signal)
    
    plt.plot(fftabs1)
    plt.plot(amplitude_envelope)

# %%
calc_R('hi.wav')

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
    analytic_signal = hilbert(fftabs1)
    amplitude_envelope = np.abs(analytic_signal)
    
    plt.plot(fftabs1)
    plt.plot(amplitude_envelope)

# %%
calc_R('hi.wav')

# %%
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1, fftabs1, 4)
    p = np.poly1d(z)
    plt.plot(freqs1,p(freqs1), 'b-',label="Polyfit")
    
    
    
    plt.plot(fftabs1)

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1, fftabs1, 4)
    p = np.poly1d(z)
    fig = plt.figure()
    ax  = fig.add_subplot(111)
    plt.plot(freqs1,p(freqs1), 'b-',label="Polyfit")
    plt.plot(fftabs1, fftabs1 'bo', label="Data")

# %%
calc_R('hi.wav')

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1, fftabs1, 4)
    p = np.poly1d(z)
    fig = plt.figure()
    ax  = fig.add_subplot(111)
    plt.plot(freqs1,p(freqs1), 'b-',label="Polyfit")
    plt.plot(fftabs1, fftabs1, 'bo', label="Data")
# Out:
#   File "<ipython-input-20-c67afcc25940>", line 43
#     plt.plot(fftabs1, fftabs1 'bo', label="Data")
#                                  ^
# SyntaxError: invalid syntax

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1, fftabs1, 3)
    p = np.poly1d(z)
    fig = plt.figure()
    ax  = fig.add_subplot(111)
    plt.plot(freqs1,p(freqs1), 'b-',label="Polyfit")
    plt.plot(fftabs1, fftabs1, 'bo', label="Data")

# %%
calc_R('hi.wav')

# %%
calc_R('lo2.wav')

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 8)
    p = np.poly1d(z)
    fig = plt.figure()
    ax  = fig.add_subplot(111)
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-',label="Polyfit")
    plt.plot(fftabs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 'bo', label="Data")

# %%
calc_R('lo2.wav')

# %%
calc_R('hi.wav')

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 15)
    p = np.poly1d(z)
    fig = plt.figure()
    ax  = fig.add_subplot(111)
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-',label="Polyfit")
    plt.plot(fftabs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 'bo', label="Data")

# %%
calc_R('hi.wav')

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 15)
    p = np.poly1d(z)
    fig = plt.figure()
    ax  = fig.add_subplot(111)
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-',label="Polyfit")
    plt.plot(fftabs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 'bo', label="Data")

# %%
calc_R('hi.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned

# %%
calc_R('lo2.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned

# %%
calc_R('goal.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned

# %%
calc_R('lo1.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned

# %%
calc_R('low.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 15)
    p = np.poly1d(z)
    
    
    
    
    plt.subplot(1, 3, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-',label="Polyfit")
    
    plt.subplot(1, 3, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(fftabs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 'bo', label="Data")

    plt.subplot(1, 3, 3)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('low.wav')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a5e6a79d7753> in <module>()
# ----> 1 calc_R('low.wav')
#
# <ipython-input-1-4923cc33a214> in calc_R(path)
#       1 def calc_R(path):
# ----> 2     y, sr = librosa.load(path)
#       3     S_full, phase = librosa.magphase(librosa.stft(y))
#       4     S_filter = librosa.decompose.nn_filter(S_full,
#       5                                        aggregate=np.median,
#
# NameError: global name 'librosa' is not defined

# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
import librosa
import IPython.display
import librosa.display
# %matplotlib inline
from scipy.signal import butter, lfilter, freqz
from scipy.fftpack import fft
from scipy.fftpack import fft,fftfreq
from scipy import stats
from scipy.stats import gmean
from scipy.stats import moment
# Out:
# /usr/local/lib/python2.7/dist-packages/librosa/__init__.py:40: DeprecationWarning: You are using librosa with Python 2. Please note that librosa 0.7 will be the last version to support Python 2, after which it will require Python 3 or later.
#   DeprecationWarning)

# %%
calc_R('low.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 15)
    p = np.poly1d(z)
    
    
    
    
    plt.subplot(1, 3, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-',label="Polyfit")
    
    plt.subplot(1, 3, 2)
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(fftabs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 'bo', label="Data")

    plt.subplot(1, 3, 3)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('low.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 15)
    p = np.poly1d(z)
    
    
    
    
    plt.subplot(1, 3, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')
    
    plt.subplot(1, 3, 2)
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(fftabs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 'r-')

    plt.subplot(1, 3, 3)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('low.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 15)
    p = np.poly1d(z)
    
    
    
    
    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')
    
    

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('low.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 15)
    p = np.poly1d(z)
    
    print(p(freqs1[:int(freqs1.size/2)]).shape)
    
    
    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')
    
    

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('low.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned

# %%
calc_R('hi.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned

# %%
calc_R('goal.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned

# %%
calc_R('lo2.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 30)
    p = np.poly1d(z)
    
    print(p(freqs1[:int(freqs1.size/2)]).shape)
    
    
    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')
    
    

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('lo2.wav')
# Out:
# (110080,)

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 30)
    p = np.poly1d(z)
    
    print(p(freqs1[:int(freqs1.size/2)]).shape)
    
    
    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')

# %%
calc_R('lo2.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# (110080,)

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 25)
    p = np.poly1d(z)
    
    print(p(freqs1[:int(freqs1.size/2)]))
    
    
    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')
    
    

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('lo2.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# (110080,)

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 6)
    p = np.poly1d(z)
    
    print(p(freqs1[:int(freqs1.size/2)]))
    
    
    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')
    
    

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('lo2.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# [ 0.31136165  0.31227477  0.31318729 ... -0.00060591 -0.00060918
#  -0.00061245]

# %%
calc_R('goal.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# [0.5324965  0.53162002 0.53074442 ... 0.04094282 0.04108693 0.0412313 ]

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 16)
    p = np.poly1d(z)
    
    print(p(freqs1[:int(freqs1.size/2)]))
    
    
    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')
    
    

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('goal.wav')
# Out:
# [-0.04806574 -0.04773907 -0.04741245 ... -0.23434028 -0.23444831
#  -0.23455635]

# %%
calc_R('lo2.wav')
# Out:
# [ 1.11535836  1.11533722  1.11531608 ... -0.0262763  -0.02628945
#  -0.02630261]

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 16)
    p = np.poly1d(z)
    
    #print(p(freqs1[:int(freqs1.size/2)]))
    
    
    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')
    
    

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('lo2.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# [0.30033653 0.30127689 0.30221664 ... 0.00696723 0.00698396 0.00700067]

# %%
calc_R('hi.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# [0.1903559  0.19025634 0.19015699 ... 0.11694314 0.1172213  0.11749975]

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 16)
    p = np.poly1d(z)
    
    #print(p(freqs1[:int(freqs1.size/2)]))
    #Moment=[]
    #for i in range(0,9):
        #j = moment(p(freqs1[:int(freqs1.size/2)]), moment=i)
        #Moment.append(j)
        
    Features = []
    
    Features.append(stats.describe(p(freqs1[:int(freqs1.size/2)])))
    
    Features.append(gmean(p(freqs1[:int(freqs1.size/2)])))
    
    cent = librosa.feature.spectral_centroid(y=y_hat1, sr=sr)
    
    a =0.0
    b = 0.0
    R = 0.0

    for i in np.nditer(cent):
        if i > K:
            a=+ i
        else:
            b=+i
        
    R = a/b
    Features.append(R)
    
    print(Features)

    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('hi.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# /usr/local/lib/python2.7/dist-packages/scipy/stats/stats.py:316: RuntimeWarning: invalid value encountered in log
#   log_a = np.log(a)
# DescribeResult(nobs=110080, minmax=(-0.04512054731122078, 1.6204224987711378), mean=0.2899408283932414, variance=0.18594936632034156, skewness=1.683963801608234, kurtosis=1.9054012238159208)
# nan
# [1.0, 0.0, 0.18594767710008067, 0.13502646185278439, 0.16961179485654834, 0.19666573627573714, 0.24010038409753587, 0.2955835938178568, 0.3682194284925752]

# %%
calc_R('goal.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# DescribeResult(nobs=110080, minmax=(-0.022688217827238732, 1.7378838889224455), mean=0.2518895629304939, variance=0.17939780625526092, skewness=2.290376860934474, kurtosis=4.291117379440943)
# nan
# [1.0, 0.0, 0.17939617655135234, 0.17403104243325165, 0.2346499443047881, 0.31041101112370856, 0.4223571726425334, 0.5817326572977324, 0.8094863757564795]

# %%
calc_R('lo2.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# DescribeResult(nobs=110080, minmax=(-0.002276313530651164, 1.3035574759887567), mean=0.19037150000893457, variance=0.09628462186637202, skewness=1.9691031343403609, kurtosis=3.1253321567955314)
# nan
# [1.0, 0.0, 0.09628374718775767, 0.058829876853322714, 0.05678525911115396, 0.05399584735626134, 0.05397072366181872, 0.05499776829748744, 0.05688078085570075]

# %%
calc_R('lo1.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# DescribeResult(nobs=110080, minmax=(-0.02744140024337338, 0.9110425742939303), mean=0.19093680944976943, variance=0.08233513083308708, skewness=1.5718476368747458, kurtosis=0.9236012317969688)
# nan
# [1.0, 0.0, 0.08233438287586657, 0.0371349033981705, 0.026597898938378765, 0.017064984462756144, 0.011420860965217172, 0.007632762327375779, 0.005141588823345749]

# %%
calc_R('low.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# DescribeResult(nobs=110080, minmax=(-0.2451804989820538, 0.9641528664628076), mean=0.11398473721984334, variance=0.042419792688259496, skewness=2.7485218348929403, kurtosis=7.027151437019139)
# nan
# [1.0, 0.0, 0.04241940733403812, 0.024012981491067998, 0.018042917647610707, 0.013604155673924617, 0.010541858384903081, 0.008283039679475362, 0.006580464647332409]

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 16)
    p = np.poly1d(z)
    
    #print(p(freqs1[:int(freqs1.size/2)]))
    #Moment=[]
    #for i in range(0,9):
        #j = moment(p(freqs1[:int(freqs1.size/2)]), moment=i)
        #Moment.append(j)
        
    Features = []
    
    Features.append(stats.describe(p(freqs1[:int(freqs1.size/2)])))
    
    Features.append(gmean(p(freqs1[:int(freqs1.size/2)])))
    
    cent = librosa.feature.spectral_centroid(y=y_hat1, sr=sr)
    
    a =0.0
    b = 0.0
    R = 0.0

    for i in np.nditer(cent):
        if i > 1500:
            a=+ i
        else:
            b=+i
        
    R = a/b
    Features.append(R)
    
    print(Features)

    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('low.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-a5e6a79d7753> in <module>()
# ----> 1 calc_R('low.wav')
#
# <ipython-input-37-eaa8e7954d89> in calc_R(path)
#      58
#      59     for i in np.nditer(cent):
# ---> 60         if i > K:
#      61             a=+ i
#      62         else:
#
# NameError: global name 'K' is not defined

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 16)
    p = np.poly1d(z)
    
    #print(p(freqs1[:int(freqs1.size/2)]))
    #Moment=[]
    #for i in range(0,9):
        #j = moment(p(freqs1[:int(freqs1.size/2)]), moment=i)
        #Moment.append(j)
        
    Features = []
    
    Features.append(stats.describe(p(freqs1[:int(freqs1.size/2)])))
    
    Features.append(gmean(p(freqs1[:int(freqs1.size/2)])))
    
    cent = librosa.feature.spectral_centroid(y=y_hat1, sr=sr)
    
    a =0.0
    b = 0.0
    R = 0.0

    for i in np.nditer(cent):
        if i > 1500:
            a=+ i
        else:
            b=+i
        
    R = a/b
    Features.append(R)
    
    print(Features)

    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('low.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# [DescribeResult(nobs=110080, minmax=(-0.2451804989820538, 0.9641528664628076), mean=0.11398473721984334, variance=0.042419792688259496, skewness=2.7485218348929403, kurtosis=7.027151437019139), nan, 1.2391000087179902]

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 16)
    p = np.poly1d(z)
    
    #print(p(freqs1[:int(freqs1.size/2)]))
    #Moment=[]
    #for i in range(0,9):
        #j = moment(p(freqs1[:int(freqs1.size/2)]), moment=i)
        #Moment.append(j)
        
    Features = []
    
    dis = stats.describe(p(freqs1[:int(freqs1.size/2)]))
    
    print(dis[0])
    
    Features.append(stats.describe(p(freqs1[:int(freqs1.size/2)])))
    
    Features.append(gmean(p(freqs1[:int(freqs1.size/2)])))
    
    cent = librosa.feature.spectral_centroid(y=y_hat1, sr=sr)
    
    a =0.0
    b = 0.0
    R = 0.0

    for i in np.nditer(cent):
        if i > 1500:
            a=+ i
        else:
            b=+i
        
    R = a/b
    Features.append(R)
    
    print(Features)

    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('low.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-a5e6a79d7753> in <module>()
# ----> 1 calc_R('low.wav')
#
# <ipython-input-41-82d82bcdfb2c> in calc_R(path)
#      49     dis = stats.describe(p(freqs1[:int(freqs1.size/2)]))
#      50
# ---> 51     print(dis.shape)
#      52
#      53     Features.append(stats.describe(p(freqs1[:int(freqs1.size/2)])))
#
# AttributeError: 'DescribeResult' object has no attribute 'shape'

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 16)
    p = np.poly1d(z)
    
    #print(p(freqs1[:int(freqs1.size/2)]))
    #Moment=[]
    #for i in range(0,9):
        #j = moment(p(freqs1[:int(freqs1.size/2)]), moment=i)
        #Moment.append(j)
        
    Features = []
    
    dis = stats.describe(p(freqs1[:int(freqs1.size/2)]))
    
    print(dis[0])
    
    Features.append(stats.describe(p(freqs1[:int(freqs1.size/2)])))
    
    Features.append(gmean(p(freqs1[:int(freqs1.size/2)])))
    
    cent = librosa.feature.spectral_centroid(y=y_hat1, sr=sr)
    
    a =0.0
    b = 0.0
    R = 0.0

    for i in np.nditer(cent):
        if i > 1500:
            a=+ i
        else:
            b=+i
        
    R = a/b
    Features.append(R)
    
    print(Features)

    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('low.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# 110080
# [DescribeResult(nobs=110080, minmax=(-0.2451804989820538, 0.9641528664628076), mean=0.11398473721984334, variance=0.042419792688259496, skewness=2.7485218348929403, kurtosis=7.027151437019139), nan, 1.2391000087179902]

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 16)
    p = np.poly1d(z)
    
    #print(p(freqs1[:int(freqs1.size/2)]))
    #Moment=[]
    #for i in range(0,9):
        #j = moment(p(freqs1[:int(freqs1.size/2)]), moment=i)
        #Moment.append(j)
        
    Features = []
    
    dis = stats.describe(p(freqs1[:int(freqs1.size/2)]))
    
    Features.append(dis[2])
    Features.append(dis[3])
    Features.append(dis[4])
    Features.append(dis[5])
    Features.append(gmean(fftabs1[:int(freqs1.size/2)]))
    
    cent = librosa.feature.spectral_centroid(y=y_hat1, sr=sr)
    
    a =0.0
    b = 0.0
    R = 0.0

    for i in np.nditer(cent):
        if i > 1500:
            a=+ i
        else:
            b=+i
        
    R = a/b
    Features.append(R)
    
    print(Features)

    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('low.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# 110080
# (-0.2451804989820538, 0.9641528664628076)
# 0.11398473721984334
# [DescribeResult(nobs=110080, minmax=(-0.2451804989820538, 0.9641528664628076), mean=0.11398473721984334, variance=0.042419792688259496, skewness=2.7485218348929403, kurtosis=7.027151437019139), nan, 1.2391000087179902]

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)
    
#mfcc = librosa.feature.mfcc(y=y_hat, sr=sr,  n_mfcc=12)
#mfcc1 = librosa.feature.mfcc(y=y_hat1, sr=sr,  n_mfcc=12)

    plt.figure(figsize=(10, 4))

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 16)
    p = np.poly1d(z)
    
    #print(p(freqs1[:int(freqs1.size/2)]))
    #Moment=[]
    #for i in range(0,9):
        #j = moment(p(freqs1[:int(freqs1.size/2)]), moment=i)
        #Moment.append(j)
        
    Features = []
    
    dis = stats.describe(p(freqs1[:int(freqs1.size/2)]))
    g_mean = gmean(fftabs1[:int(freqs1.size/2)])
    cent = librosa.feature.spectral_centroid(y=y_hat1, sr=sr)
    
    a =0.0
    b = 0.0
    R = 0.0

    for i in np.nditer(cent):
        if i > 1500:
            a=+ i
        else:
            b=+i
        
    R = a/b
    
    Features.append(round(dis[2],4))
    Features.append(round(dis[3],4))
    Features.append(round(dis[4],4))
    Features.append(round(dis[5],4))
    Features.append(round(g_mean,4))
    Features.append(round(R,4))
    
    print(Features)

    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('low.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# [0.11398473721984334, 0.042419792688259496, 2.7485218348929403, 7.027151437019139, 0.029734781, 1.2391000087179902]

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 16)
    p = np.poly1d(z)
        
    Features = []
    
    dis = stats.describe(p(freqs1[:int(freqs1.size/2)]))
    g_mean = gmean(fftabs1[:int(freqs1.size/2)])
    cent = librosa.feature.spectral_centroid(y=y_hat1, sr=sr)
    
    a =0.0
    b = 0.0
    R = 0.0

    for i in np.nditer(cent):
        if i > 1500:
            a=+ i
        else:
            b=+i
        
    R = a/b
    
    Features.append(round(dis[2],4))
    Features.append(round(dis[3],4))
    Features.append(round(dis[4],4))
    Features.append(round(dis[5],4))
    Features.append(round(g_mean,4))
    Features.append(round(R,4))
    
    print(Features)

    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.ylim( [0, 5] )
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('hi.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:63: RuntimeWarning: divide by zero encountered in double_scalars
# [0.2899, 0.1859, 1.684, 1.9054, 0.0663, inf]

# %%
calc_R('lo2.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# [0.1904, 0.0963, 1.9691, 3.1253, 0.038, 1.0059]

# %%
calc_R('lo1.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# [0.1909, 0.0823, 1.5718, 0.9236, 0.0468, 1.3762]

# %%
calc_R('goal.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:38: RankWarning: Polyfit may be poorly conditioned
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:63: RuntimeWarning: divide by zero encountered in double_scalars
# [0.2519, 0.1794, 2.2904, 4.2911, 0.0675, inf]

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 16)
    p = np.poly1d(z)
        
    Features = []
    
    dis = stats.describe(p(freqs1[:int(freqs1.size/2)]))
    g_mean = gmean(fftabs1[:int(freqs1.size/2)])
    cent = librosa.feature.spectral_centroid(y=y_hat1, sr=sr)
    
    a =0.0
    b = 0.0
    R = 0.0

    for i in np.nditer(cent):
        if i > 1500:
            a=+ i
        else:
            b=+i
        
    R = a/b
    
    Features.append(round(dis[2],4))
    Features.append(round(dis[3],4))
    Features.append(round(dis[4],4))
    Features.append(round(dis[5],4))
    Features.append(round(g_mean,4))
    Features.append(round(R,4))
    
    print(Features)

    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])

# %%
calc_R('goal.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:33: RankWarning: Polyfit may be poorly conditioned
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:52: RuntimeWarning: divide by zero encountered in double_scalars
# [0.2519, 0.1794, 2.2904, 4.2911, 0.0675, inf]

# %%
def calc_R(path,t):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], t)
    p = np.poly1d(z)
        
    Features = []
    
    dis = stats.describe(p(freqs1[:int(freqs1.size/2)]))
    g_mean = gmean(fftabs1[:int(freqs1.size/2)])
    cent = librosa.feature.spectral_centroid(y=y_hat1, sr=sr)
    
    a =0.0
    b = 0.0
    R = 0.0

    for i in np.nditer(cent):
        if i > 1500:
            a=+ i
        else:
            b=+i
        
    R = a/b
    
    Features.append(round(dis[2],4))
    Features.append(round(dis[3],4))
    Features.append(round(dis[4],4))
    Features.append(round(dis[5],4))
    Features.append(round(g_mean,4))
    Features.append(round(R,4))
    
    print(Features)

    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],fftabs1[:int(freqs1.size/2)])
    
    print(freqs1.size)

# %%
calc_R('goal.wav',10)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:52: RuntimeWarning: divide by zero encountered in double_scalars
# [0.2519, 0.167, 1.8967, 2.32, 0.0675, inf]

# %%
calc_R('lo1.wav',10)
# Out:
# [0.1909, 0.0816, 1.5517, 0.8335, 0.0468, 1.3762]

# %%
calc_R('hi.wav',10)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:52: RuntimeWarning: divide by zero encountered in double_scalars
# [0.2899, 0.1764, 1.447, 0.8313, 0.0663, inf]

# %%
calc_R('lo2.wav',10)
# Out:
# [0.1904, 0.0942, 1.8204, 2.2512, 0.038, 1.0059]

# %%
calc_R('goal.wav',20)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:33: RankWarning: Polyfit may be poorly conditioned
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:52: RuntimeWarning: divide by zero encountered in double_scalars
# [0.2519, 0.1795, 2.2974, 4.3305, 0.0675, inf]

# %%
calc_R('lo1.wav',20)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:33: RankWarning: Polyfit may be poorly conditioned
# [0.1909, 0.0824, 1.5742, 0.9332, 0.0468, 1.3762]

# %%
calc_R('low.wav',20)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:33: RankWarning: Polyfit may be poorly conditioned
# [0.114, 0.0424, 2.7496, 7.0385, 0.0297, 1.2391]

# %%
def calc_R(path,t):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], t)
    p = np.poly1d(z)
        
    Features = []
    
    dis = stats.describe(p(freqs1[:int(freqs1.size/2)]))
    g_mean = gmean(fftabs1[:int(freqs1.size/2)])
    cent = librosa.feature.spectral_centroid(y=y_hat1, sr=sr)
    
    a =0.0
    b = 0.0
    R = 0.0

    for i in np.nditer(cent):
        if i > 1500:
            a=+ i
        else:
            b=+i
        
    R = a/b
    
    Features.append(round(dis[2],4))
    Features.append(round(dis[3],4))
    Features.append(round(dis[4],4))
    Features.append(round(dis[5],4))
    Features.append(round(g_mean,4))
    Features.append(round(R,4))
    
    print(Features)

    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[10000:int(freqs1.size/2)-10000],fftabs1[10000:int(freqs1.size/2)-10000])
    
    #print(freqs1.size)

# %%
calc_R('low.wav',20)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:33: RankWarning: Polyfit may be poorly conditioned
# [0.114, 0.0424, 2.7496, 7.0385, 0.0297, 1.2391]
# 220160

# %%
def calc_R(path,t):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], t)
    p = np.poly1d(z)
        
    Features = []
    
    dis = stats.describe(p(freqs1[:int(freqs1.size/2)]))
    g_mean = gmean(fftabs1[:int(freqs1.size/2)])
    cent = librosa.feature.spectral_centroid(y=y_hat1, sr=sr)
    
    a =0.0
    b = 0.0
    R = 0.0

    for i in np.nditer(cent):
        if i > 1500:
            a=+ i
        else:
            b=+i
        
    R = a/b
    
    Features.append(round(dis[2],4))
    Features.append(round(dis[3],4))
    Features.append(round(dis[4],4))
    Features.append(round(dis[5],4))
    Features.append(round(g_mean,4))
    Features.append(round(R,4))
    
    print(Features)

    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[1000:int(freqs1.size/2)-1000],fftabs1[1000:int(freqs1.size/2)-1000])

# %%
calc_R('low.wav',20)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:33: RankWarning: Polyfit may be poorly conditioned
# [0.114, 0.0424, 2.7496, 7.0385, 0.0297, 1.2391]

# %%
def calc_R(path,t):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], t)
    p = np.poly1d(z)
        
    Features = []
    
    dis = stats.describe(p(freqs1[:int(freqs1.size/2)]))
    g_mean = gmean(fftabs1[:int(freqs1.size/2)])
    cent = librosa.feature.spectral_centroid(y=y_hat1, sr=sr)
    
    a =0.0
    b = 0.0
    R = 0.0

    for i in np.nditer(cent):
        if i > 1500:
            a=+ i
        else:
            b=+i
        
    R = a/b
    
    Features.append(round(dis[2],4))
    Features.append(round(dis[3],4))
    Features.append(round(dis[4],4))
    Features.append(round(dis[5],4))
    Features.append(round(g_mean,4))
    Features.append(round(R,4))
    
    print(Features)

    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[0:int(freqs1.size/2)],fftabs1[0:int(freqs1.size/2)])

# %%
calc_R('low.wav',20)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:33: RankWarning: Polyfit may be poorly conditioned
# [0.114, 0.0424, 2.7496, 7.0385, 0.0297, 1.2391]

# %%
calc_R('goal.wav',20)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:33: RankWarning: Polyfit may be poorly conditioned
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:52: RuntimeWarning: divide by zero encountered in double_scalars
# [0.2519, 0.1795, 2.2974, 4.3305, 0.0675, inf]

# %%
calc_R('lo1.wav',20)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:33: RankWarning: Polyfit may be poorly conditioned
# [0.1909, 0.0824, 1.5742, 0.9332, 0.0468, 1.3762]

# %%
def calc_R(path):
    y, sr = librosa.load(path)
    S_full, phase = librosa.magphase(librosa.stft(y))
    S_filter = librosa.decompose.nn_filter(S_full,
                                       aggregate=np.median,
                                       metric='cosine',
                                       width=int(librosa.time_to_frames(2, sr=sr)))
    S_filter = np.minimum(S_full, S_filter)
    margin_i, margin_v = 2, 10
    power = 2

    mask_i = librosa.util.softmask(S_filter,
                               margin_i * (S_full - S_filter),
                               power=power)

    mask_v = librosa.util.softmask(S_full - S_filter,
                               margin_v * S_filter,
                               power=power)
    
    S_foreground = mask_v * S_full
    S_background = mask_i * S_full
    
    y_hat = librosa.istft(S_foreground)
    y_hat1 = librosa.istft(S_background)

   
    samples = y_hat.shape[0]
    
    datafft1 = fft(y_hat1)
    fftabs1 = abs(datafft1)
    freqs1 = fftfreq(samples,1.0/sr)
   
    z = np.polyfit(freqs1[:int(freqs1.size/2)], fftabs1[:int(freqs1.size/2)], 18)
    p = np.poly1d(z)
        
    Features = []
    
    dis = stats.describe(p(freqs1[:int(freqs1.size/2)]))
    g_mean = gmean(fftabs1[:int(freqs1.size/2)])
    cent = librosa.feature.spectral_centroid(y=y_hat1, sr=sr)
    
    a =0.0
    b = 0.0
    R = 0.0

    for i in np.nditer(cent):
        if i > 1500:
            a=+ i
        else:
            b=+i
        
    R = a/b
    
    Features.append(round(dis[2],4))
    Features.append(round(dis[3],4))
    Features.append(round(dis[4],4))
    Features.append(round(dis[5],4))
    Features.append(round(g_mean,4))
    Features.append(round(R,4))
    
    print(Features)

    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[:int(freqs1.size/2)],p(freqs1[:int(freqs1.size/2)]), 'b-')

    plt.subplot(1, 2, 2)
    plt.xlim( [10, sr/2] )
    plt.xscale( 'log' )
    plt.grid( True )
    plt.xlabel( 'Frequency (Hz)' )
    plt.plot(freqs1[0:int(freqs1.size/2)],fftabs1[0:int(freqs1.size/2)])

# %%
calc_R('lo1.wav')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:33: RankWarning: Polyfit may be poorly conditioned
# [0.1909, 0.0821, 1.5675, 0.9026, 0.0468, 1.3762]
